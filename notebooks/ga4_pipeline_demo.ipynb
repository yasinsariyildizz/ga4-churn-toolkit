# %% [markdown]
# # GA4 Analysis Pipeline — Architecture Demo
#
# This notebook validates the final package architecture before churn logic is added.
#
# **Metrics:** users, sessions, purchase events, revenue, event count.

# %% [markdown]
# ## 1. Install

# %%
# During GitHub testing:
# %pip install -q "ga4-churn-toolkit @ git+https://github.com/yasinsariyildizz/ga4-churn-toolkit.git@main"

# After PyPI publication, replace the line above with:
# %pip install -q "ga4-churn-toolkit==0.0.1"

# %% [markdown]
# ## 2. Import

# %%
from ga4_churn import GA4Analysis

# %% [markdown]
# ## 3. Inputs — edit only this cell

# %%
PROJECT_ID = "your-gcp-project"
DATASET_ID = "analytics_123456789"
OUTPUT_DATASET = "ga4_analysis_demo"

START_DATE = "2026-08-01"
END_DATE = "2026-08-31"

# %% [markdown]
# ## 4. Initialize

# %%
analysis = GA4Analysis(
    project_id=PROJECT_ID,
    dataset_id=DATASET_ID,
    output_dataset=OUTPUT_DATASET,
    start_date=START_DATE,
    end_date=END_DATE,
)

# %% [markdown]
# ## 5. Validate & Dry Run

# %%
analysis.validate()

# %%
analysis.dry_run()

# %% [markdown]
# ## 6. Run steps separately

# %%
analysis.run_step(1)

# %%
analysis.run_step(2)

# %%
analysis.run_step(3)

# %%
analysis.run_step(4)

# %% [markdown]
# ## 7. Or run everything in one call

# %%
# Use this instead of the four cells above when you want the full pipeline.
# analysis.run_all()
