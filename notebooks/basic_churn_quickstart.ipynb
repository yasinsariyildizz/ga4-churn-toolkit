# %% [markdown]
# # GA4 Basic Churn Analysis
#
# Minimal purchase-based churn workflow for GA4 BigQuery export data.

# %%
# %pip install -q --upgrade "ga4-churn-toolkit @ git+https://github.com/yasinsariyildizz/ga4-churn-toolkit.git@main"

# %%
from ga4_churn import ChurnAnalysis

# %% [markdown]
# ## Inputs — edit only this cell

# %%
PROJECT_ID = "your-gcp-project"
DATASET_ID = "analytics_123456789"
TABLE_ID = "events_*"
OUTPUT_DATASET_ID = "ga4_churn"

# %%
analysis = ChurnAnalysis(
    project_id=PROJECT_ID,
    dataset_id=DATASET_ID,
    table_id=TABLE_ID,
    output_dataset_id=OUTPUT_DATASET_ID,
)

# %% [markdown]
# ## 1. Dry run

# %%
analysis.dry_run()

# %% [markdown]
# ## 2. Create base table

# %%
analysis.create_base_table()

# %% [markdown]
# ## 3. Purchase day distribution

# %%
analysis.purchase_day_distribution()

# %% [markdown]
# ## 4. Churn analysis + HTML dashboard
#
# Choose the churn threshold only here. Example: 90 days.

# %%
analysis.churn_analysis(90)
